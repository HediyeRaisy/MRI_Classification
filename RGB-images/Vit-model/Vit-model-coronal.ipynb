# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
from torch.utils.data import DataLoader, Dataset
from sklearn.model_selection import KFold
from sklearn.metrics import f1_score
from PIL import Image
import pandas as pd
# !pip install timm
import timm  
import numpy as np
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: timm in /home/hedieh/.local/lib/python3.9/site-packages (0.9.10)
# Requirement already satisfied: torch>=1.7 in /home/hedieh/.local/lib/python3.9/site-packages (from timm) (2.0.1+cu118)
# Requirement already satisfied: torchvision in /home/hedieh/.local/lib/python3.9/site-packages (from timm) (0.15.2+cu118)
# Requirement already satisfied: pyyaml in /usr/lib/python3/dist-packages (from timm) (5.3.1)
# Requirement already satisfied: huggingface-hub in /home/hedieh/.local/lib/python3.9/site-packages (from timm) (0.19.0)
# Requirement already satisfied: safetensors in /home/hedieh/.local/lib/python3.9/site-packages (from timm) (0.4.0)
# Requirement already satisfied: networkx in /home/hedieh/.local/lib/python3.9/site-packages (from torch>=1.7->timm) (3.0)
# Requirement already satisfied: sympy in /home/hedieh/.local/lib/python3.9/site-packages (from torch>=1.7->timm) (1.12)
# Requirement already satisfied: typing-extensions in /home/hedieh/.local/lib/python3.9/site-packages (from torch>=1.7->timm) (4.5.0)
# Requirement already satisfied: jinja2 in /home/hedieh/.local/lib/python3.9/site-packages (from torch>=1.7->timm) (3.1.2)
# Requirement already satisfied: filelock in /home/hedieh/.local/lib/python3.9/site-packages (from torch>=1.7->timm) (3.12.2)
# Requirement already satisfied: triton==2.0.0 in /home/hedieh/.local/lib/python3.9/site-packages (from torch>=1.7->timm) (2.0.0)
# Requirement already satisfied: lit in /home/hedieh/.local/lib/python3.9/site-packages (from triton==2.0.0->torch>=1.7->timm) (16.0.5.post0)
# Requirement already satisfied: cmake in /home/hedieh/.local/lib/python3.9/site-packages (from triton==2.0.0->torch>=1.7->timm) (3.26.4)
# Requirement already satisfied: tqdm>=4.42.1 in /home/hedieh/.local/lib/python3.9/site-packages (from huggingface-hub->timm) (4.66.1)
# Requirement already satisfied: packaging>=20.9 in /home/hedieh/.local/lib/python3.9/site-packages (from huggingface-hub->timm) (23.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/hedieh/.local/lib/python3.9/site-packages (from huggingface-hub->timm) (2023.10.0)
# Requirement already satisfied: requests in /home/hedieh/.local/lib/python3.9/site-packages (from huggingface-hub->timm) (2.28.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from torchvision->timm) (1.24.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/hedieh/.local/lib/python3.9/site-packages (from torchvision->timm) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/hedieh/.local/lib/python3.9/site-packages (from jinja2->torch>=1.7->timm) (2.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/hedieh/.local/lib/python3.9/site-packages (from requests->huggingface-hub->timm) (3.1.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/lib/python3/dist-packages (from requests->huggingface-hub->timm) (1.26.5)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests->huggingface-hub->timm) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests->huggingface-hub->timm) (2020.6.20)
# Requirement already satisfied: mpmath>=0.19 in /home/hedieh/.local/lib/python3.9/site-packages (from sympy->torch>=1.7->timm) (1.3.0)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.3.1
# [notice] To update, run: /usr/bin/python3 -m pip install --upgrade pip

# %%
def path_data_axial(category,patient):
    path = "./data/images/"+category+"/axial/"+patient+".png"
    return path
def path_data_sagital(category,patient):
    path = "./data/images/"+category+"/sagital/"+patient+".png"
    return path
def path_data_coronal(category,patient):
    path = "./data/images/"+category+"/coronal/"+patient+".png"
    return path

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cuda'

# %%
# Load data
total_data = pd.read_csv("./total_data.csv")
total_data = total_data[(total_data["Research Group"] != "MCI")]
total_data = total_data.reset_index()
PID = total_data["Subject ID"]
Labels = total_data["Research Group"]

# %%
# Prepare data
data = []
new_labels = []
for label in Labels:
    if label == "CN":
        new_labels.append(0)
    elif label == "AD":
        new_labels.append(1)

# %%
for i in range(len(PID)):
    # Example: using axial images
    img_path = path_data_coronal(Labels[i], PID[i])  # Replace "Category_Name" with actual category
    data.append((img_path, new_labels[i]))
    
data
# Out:
# [('./data/images/CN/coronal/002_S_0295.png', 0),
#  ('./data/images/CN/coronal/002_S_0413.png', 0),
#  ('./data/images/CN/coronal/002_S_0559.png', 0),
#  ('./data/images/AD/coronal/002_S_0619.png', 1),
#  ('./data/images/CN/coronal/002_S_0685.png', 0),
#  ('./data/images/AD/coronal/002_S_0816.png', 1),
#  ('./data/images/AD/coronal/002_S_0938.png', 1),
#  ('./data/images/AD/coronal/002_S_0955.png', 1),
#  ('./data/images/AD/coronal/002_S_1018.png', 1),
#  ('./data/images/CN/coronal/002_S_1261.png', 0),
#  ('./data/images/CN/coronal/002_S_1280.png', 0),
#  ('./data/images/CN/coronal/002_S_4213.png', 0),
#  ('./data/images/CN/coronal/002_S_4225.png', 0),
#  ('./data/images/CN/coronal/002_S_4262.png', 0),
#  ('./data/images/CN/coronal/002_S_4264.png', 0),
#  ('./data/images/CN/coronal/002_S_4270.png', 0),
#  ('./data/images/AD/coronal/002_S_5018.png', 1),
#  ('./data/images/CN/coronal/002_S_6053.png', 0),
#  ('./data/images/CN/coronal/003_S_0907.png', 0),
#  ('./data/images/CN/coronal/003_S_0981.png', 0),
#  ('./data/images/CN/coronal/003_S_1021.png', 0),
#  ('./data/images/AD/coronal/003_S_1059.png', 1),
#  ('./data/images/AD/coronal/003_S_1257.png', 1),
#  ('./data/images/CN/coronal/003_S_4081.png', 0),
#  ('./data/images/CN/coronal/003_S_4118.png', 0),
#  ('./data/images/CN/coronal/003_S_4119.png', 0),
#  ('./data/images/AD/coronal/003_S_4136.png', 1),
#  ('./data/images/AD/coronal/003_S_4142.png', 1),
#  ('./data/images/AD/coronal/003_S_4152.png', 1),
#  ('./data/images/CN/coronal/003_S_4288.png', 0),
#  ('./data/images/CN/coronal/003_S_4350.png', 0),
#  ('./data/images/AD/coronal/003_S_4373.png', 1),
#  ('./data/images/CN/coronal/003_S_4441.png', 0),
#  ('./data/images/CN/coronal/003_S_4555.png', 0),
#  ('./data/images/CN/coronal/003_S_4644.png', 0),
#  ('./data/images/CN/coronal/003_S_4839.png', 0),
#  ('./data/images/CN/coronal/003_S_4840.png', 0),
#  ('./data/images/CN/coronal/003_S_4872.png', 0),
#  ('./data/images/AD/coronal/003_S_4892.png', 1),
#  ('./data/images/CN/coronal/003_S_4900.png', 0),
#  ('./data/images/AD/coronal/003_S_5165.png', 1),
#  ('./data/images/AD/coronal/003_S_5187.png', 1),
#  ('./data/images/AD/coronal/005_S_0221.png', 1),
#  ('./data/images/CN/coronal/005_S_0223.png', 0),
#  ('./data/images/CN/coronal/005_S_0553.png', 0),
#  ('./data/images/CN/coronal/005_S_0602.png', 0),
#  ('./data/images/CN/coronal/005_S_0610.png', 0),
#  ('./data/images/AD/coronal/005_S_0814.png', 1),
#  ('./data/images/AD/coronal/005_S_0929.png', 1),
#  ('./data/images/AD/coronal/005_S_1341.png', 1),
#  ('./data/images/AD/coronal/005_S_4707.png', 1),
#  ('./data/images/AD/coronal/005_S_4910.png', 1),
#  ('./data/images/AD/coronal/005_S_5038.png', 1),
#  ('./data/images/AD/coronal/005_S_5119.png', 1),
#  ('./data/images/CN/coronal/006_S_0484.png', 0),
#  ('./data/images/CN/coronal/006_S_0498.png', 0),
#  ('./data/images/AD/coronal/006_S_0547.png', 1),
#  ('./data/images/AD/coronal/006_S_0653.png', 1),
#  ('./data/images/CN/coronal/006_S_0681.png', 0),
#  ('./data/images/CN/coronal/006_S_0731.png', 0),
#  ('./data/images/CN/coronal/006_S_4150.png', 0),
#  ('./data/images/AD/coronal/006_S_4153.png', 1),
#  ('./data/images/AD/coronal/006_S_4192.png', 1),
#  ('./data/images/CN/coronal/006_S_4357.png', 0),
#  ('./data/images/CN/coronal/006_S_4449.png', 0),
#  ('./data/images/CN/coronal/006_S_4485.png', 0),
#  ('./data/images/AD/coronal/006_S_4546.png', 1),
#  ('./data/images/AD/coronal/006_S_4867.png', 1),
#  ('./data/images/CN/coronal/007_S_0068.png', 0),
#  ('./data/images/CN/coronal/007_S_0070.png', 0),
#  ('./data/images/AD/coronal/007_S_0316.png', 1),
#  ('./data/images/CN/coronal/007_S_1206.png', 0),
#  ('./data/images/CN/coronal/007_S_1222.png', 0),
#  ('./data/images/AD/coronal/007_S_1248.png', 1),
#  ('./data/images/AD/coronal/007_S_1304.png', 1),
#  ('./data/images/AD/coronal/007_S_1339.png', 1),
#  ('./data/images/CN/coronal/007_S_4387.png', 0),
#  ('./data/images/CN/coronal/007_S_4488.png', 0),
#  ('./data/images/CN/coronal/007_S_4516.png', 0),
#  ('./data/images/AD/coronal/007_S_4568.png', 1),
#  ('./data/images/CN/coronal/007_S_4620.png', 0),
#  ('./data/images/CN/coronal/007_S_4637.png', 0),
#  ('./data/images/AD/coronal/007_S_4911.png', 1),
#  ('./data/images/AD/coronal/007_S_5196.png', 1),
#  ('./data/images/CN/coronal/009_S_0751.png', 0),
#  ('./data/images/CN/coronal/009_S_0842.png', 0),
#  ('./data/images/CN/coronal/009_S_0862.png', 0),
#  ('./data/images/AD/coronal/009_S_1334.png', 1),
#  ('./data/images/AD/coronal/009_S_1354.png', 1),
#  ('./data/images/CN/coronal/009_S_4337.png', 0),
#  ('./data/images/CN/coronal/009_S_4388.png', 0),
#  ('./data/images/CN/coronal/009_S_4612.png', 0),
#  ('./data/images/AD/coronal/009_S_5027.png', 1),
#  ('./data/images/AD/coronal/009_S_5037.png', 1),
#  ('./data/images/AD/coronal/009_S_5224.png', 1),
#  ('./data/images/AD/coronal/009_S_5252.png', 1),
#  ('./data/images/CN/coronal/010_S_0067.png', 0),
#  ('./data/images/CN/coronal/010_S_0419.png', 0),
#  ('./data/images/CN/coronal/010_S_0420.png', 0),
#  ('./data/images/CN/coronal/010_S_4345.png', 0),
#  ('./data/images/CN/coronal/010_S_4442.png', 0),
#  ('./data/images/AD/coronal/010_S_5163.png', 1),
#  ('./data/images/AD/coronal/011_S_0003.png', 1),
#  ('./data/images/CN/coronal/011_S_0005.png', 0),
#  ('./data/images/CN/coronal/011_S_0008.png', 0),
#  ('./data/images/CN/coronal/011_S_0016.png', 0),
#  ('./data/images/CN/coronal/011_S_0021.png', 0),
#  ('./data/images/CN/coronal/011_S_0022.png', 0),
#  ('./data/images/CN/coronal/011_S_0023.png', 0),
#  ('./data/images/AD/coronal/011_S_0053.png', 1),
#  ('./data/images/CN/coronal/011_S_4075.png', 0),
#  ('./data/images/CN/coronal/011_S_4105.png', 0),
#  ('./data/images/CN/coronal/011_S_4120.png', 0),
#  ('./data/images/CN/coronal/011_S_4222.png', 0),
#  ('./data/images/CN/coronal/011_S_4278.png', 0),
#  ('./data/images/AD/coronal/011_S_4827.png', 1),
#  ('./data/images/AD/coronal/011_S_4845.png', 1),
#  ('./data/images/AD/coronal/011_S_4906.png', 1),
#  ('./data/images/AD/coronal/011_S_4912.png', 1),
#  ('./data/images/AD/coronal/011_S_4949.png', 1),
#  ('./data/images/CN/coronal/012_S_0637.png', 0),
#  ('./data/images/AD/coronal/012_S_0689.png', 1),
#  ('./data/images/CN/coronal/012_S_1009.png', 0),
#  ('./data/images/CN/coronal/012_S_4026.png', 0),
#  ('./data/images/CN/coronal/012_S_4545.png', 0),
#  ('./data/images/AD/coronal/013_S_0592.png', 1),
#  ('./data/images/AD/coronal/013_S_0699.png', 1),
#  ('./data/images/AD/coronal/013_S_0996.png', 1),
#  ('./data/images/AD/coronal/013_S_1161.png', 1),
#  ('./data/images/AD/coronal/013_S_1205.png', 1),
#  ('./data/images/CN/coronal/013_S_1276.png', 0),
#  ('./data/images/CN/coronal/013_S_4731.png', 0),
#  ('./data/images/AD/coronal/013_S_5071.png', 1),
#  ('./data/images/AD/coronal/014_S_0328.png', 1),
#  ('./data/images/AD/coronal/014_S_0356.png', 1),
#  ('./data/images/AD/coronal/014_S_0357.png', 1),
#  ('./data/images/AD/coronal/014_S_1095.png', 1),
#  ('./data/images/AD/coronal/014_S_4039.png', 1),
#  ('./data/images/AD/coronal/014_S_4615.png', 1),
#  ('./data/images/AD/coronal/016_S_1263.png', 1),
#  ('./data/images/AD/coronal/016_S_4009.png', 1),
#  ('./data/images/CN/coronal/016_S_4121.png', 0),
#  ('./data/images/AD/coronal/016_S_4353.png', 1),
#  ('./data/images/AD/coronal/016_S_4583.png', 1),
#  ('./data/images/AD/coronal/016_S_4591.png', 1),
#  ('./data/images/AD/coronal/016_S_4887.png', 1),
#  ('./data/images/CN/coronal/018_S_0425.png', 0),
#  ('./data/images/AD/coronal/018_S_4696.png', 1),
#  ('./data/images/AD/coronal/019_S_4252.png', 1),
#  ('./data/images/AD/coronal/019_S_4549.png', 1),
#  ('./data/images/CN/coronal/020_S_1288.png', 0),
#  ('./data/images/CN/coronal/023_S_0031.png', 0),
#  ('./data/images/CN/coronal/023_S_0061.png', 0),
#  ('./data/images/AD/coronal/023_S_0139.png', 1),
#  ('./data/images/AD/coronal/023_S_1289.png', 1),
#  ('./data/images/AD/coronal/027_S_1081.png', 1),
#  ('./data/images/AD/coronal/027_S_1385.png', 1),
#  ('./data/images/CN/coronal/029_S_4279.png', 0),
#  ('./data/images/CN/coronal/029_S_4385.png', 0),
#  ('./data/images/AD/coronal/031_S_1209.png', 1),
#  ('./data/images/CN/coronal/032_S_0677.png', 0),
#  ('./data/images/CN/coronal/037_S_0303.png', 0),
#  ('./data/images/AD/coronal/067_S_0812.png', 1),
#  ('./data/images/AD/coronal/067_S_1185.png', 1),
#  ('./data/images/AD/coronal/067_S_1253.png', 1),
#  ('./data/images/AD/coronal/094_S_4089.png', 1),
#  ('./data/images/CN/coronal/094_S_4460.png', 0),
#  ('./data/images/AD/coronal/098_S_0149.png', 1),
#  ('./data/images/CN/coronal/098_S_0172.png', 0),
#  ('./data/images/CN/coronal/100_S_0015.png', 0),
#  ('./data/images/CN/coronal/100_S_0047.png', 0),
#  ('./data/images/AD/coronal/100_S_1062.png', 1),
#  ('./data/images/CN/coronal/100_S_1286.png', 0),
#  ('./data/images/CN/coronal/123_S_0072.png', 0),
#  ('./data/images/AD/coronal/123_S_0088.png', 1),
#  ('./data/images/AD/coronal/123_S_0091.png', 1),
#  ('./data/images/AD/coronal/123_S_0094.png', 1),
#  ('./data/images/CN/coronal/123_S_0106.png', 0),
#  ('./data/images/AD/coronal/123_S_0162.png', 1),
#  ('./data/images/AD/coronal/126_S_0606.png', 1),
#  ('./data/images/AD/coronal/126_S_0784.png', 1),
#  ('./data/images/CN/coronal/127_S_0259.png', 0),
#  ('./data/images/CN/coronal/127_S_0260.png', 0),
#  ('./data/images/AD/coronal/127_S_0754.png', 1),
#  ('./data/images/AD/coronal/127_S_0844.png', 1),
#  ('./data/images/CN/coronal/129_S_4369.png', 0),
#  ('./data/images/AD/coronal/130_S_0956.png', 1),
#  ('./data/images/AD/coronal/130_S_4730.png', 1),
#  ('./data/images/AD/coronal/131_S_0691.png', 1),
#  ('./data/images/CN/coronal/133_S_0525.png', 0),
#  ('./data/images/AD/coronal/003_S_6264.png', 1),
#  ('./data/images/AD/coronal/003_S_6833.png', 1),
#  ('./data/images/AD/coronal/006_S_6689.png', 1),
#  ('./data/images/AD/coronal/011_S_0010.png', 1),
#  ('./data/images/AD/coronal/011_S_0183.png', 1),
#  ('./data/images/AD/coronal/011_S_6303.png', 1),
#  ('./data/images/AD/coronal/013_S_6768.png', 1),
#  ('./data/images/AD/coronal/013_S_6975.png', 1),
#  ('./data/images/AD/coronal/016_S_0991.png', 1),
#  ('./data/images/AD/coronal/016_S_4963.png', 1),
#  ('./data/images/AD/coronal/016_S_5032.png', 1),
#  ('./data/images/AD/coronal/016_S_5057.png', 1),
#  ('./data/images/AD/coronal/016_S_5251.png', 1),
#  ('./data/images/AD/coronal/016_S_6708.png', 1),
#  ('./data/images/AD/coronal/016_S_6839.png', 1),
#  ('./data/images/AD/coronal/018_S_0335.png', 1),
#  ('./data/images/AD/coronal/018_S_0633.png', 1),
#  ('./data/images/AD/coronal/018_S_0682.png', 1),
#  ('./data/images/AD/coronal/018_S_4733.png', 1),
#  ('./data/images/AD/coronal/018_S_5074.png', 1),
#  ('./data/images/AD/coronal/018_S_5240.png', 1),
#  ('./data/images/AD/coronal/019_S_4477.png', 1),
#  ('./data/images/AD/coronal/019_S_5012.png', 1),
#  ('./data/images/AD/coronal/019_S_5019.png', 1),
#  ('./data/images/AD/coronal/019_S_6573.png', 1),
#  ('./data/images/AD/coronal/019_S_6585.png', 1),
#  ('./data/images/AD/coronal/019_S_6712.png', 1),
#  ('./data/images/AD/coronal/020_S_0213.png', 1),
#  ('./data/images/AD/coronal/021_S_0343.png', 1),
#  ('./data/images/AD/coronal/021_S_0642.png', 1),
#  ('./data/images/AD/coronal/021_S_0753.png', 1),
#  ('./data/images/AD/coronal/021_S_1109.png', 1),
#  ('./data/images/AD/coronal/021_S_4718.png', 1),
#  ('./data/images/AD/coronal/021_S_4924.png', 1),
#  ('./data/images/AD/coronal/022_S_0007.png', 1),
#  ('./data/images/AD/coronal/022_S_0129.png', 1),
#  ('./data/images/AD/coronal/022_S_0219.png', 1),
#  ('./data/images/AD/coronal/022_S_0543.png', 1),
#  ('./data/images/AD/coronal/022_S_6013.png', 1),
#  ('./data/images/AD/coronal/022_S_6796.png', 1),
#  ('./data/images/AD/coronal/023_S_0083.png', 1),
#  ('./data/images/AD/coronal/023_S_0084.png', 1),
#  ('./data/images/AD/coronal/023_S_0093.png', 1),
#  ('./data/images/AD/coronal/023_S_0916.png', 1),
#  ('./data/images/AD/coronal/023_S_1262.png', 1),
#  ('./data/images/AD/coronal/023_S_4501.png', 1),
#  ('./data/images/AD/coronal/023_S_5120.png', 1),
#  ('./data/images/AD/coronal/023_S_5241.png', 1),
#  ('./data/images/AD/coronal/023_S_6661.png', 1),
#  ('./data/images/AD/coronal/024_S_1171.png', 1),
#  ('./data/images/AD/coronal/024_S_1307.png', 1),
#  ('./data/images/AD/coronal/024_S_4223.png', 1),
#  ('./data/images/AD/coronal/024_S_4280.png', 1),
#  ('./data/images/AD/coronal/024_S_4905.png', 1),
#  ('./data/images/AD/coronal/024_S_5054.png', 1),
#  ('./data/images/AD/coronal/027_S_0404.png', 1),
#  ('./data/images/AD/coronal/027_S_0850.png', 1),
#  ('./data/images/AD/coronal/027_S_1082.png', 1),
#  ('./data/images/AD/coronal/027_S_1254.png', 1),
#  ('./data/images/AD/coronal/027_S_4801.png', 1),
#  ('./data/images/AD/coronal/027_S_4802.png', 1),
#  ('./data/images/AD/coronal/027_S_4938.png', 1),
#  ('./data/images/AD/coronal/027_S_4962.png', 1),
#  ('./data/images/AD/coronal/027_S_4964.png', 1),
#  ('./data/images/AD/coronal/027_S_6648.png', 1),
#  ('./data/images/AD/coronal/027_S_6733.png', 1),
#  ('./data/images/AD/coronal/027_S_6849.png', 1),
#  ('./data/images/AD/coronal/027_S_6965.png', 1),
#  ('./data/images/AD/coronal/029_S_0836.png', 1),
#  ('./data/images/AD/coronal/029_S_0999.png', 1),
#  ('./data/images/AD/coronal/029_S_1056.png', 1),
#  ('./data/images/AD/coronal/029_S_1184.png', 1),
#  ('./data/images/AD/coronal/029_S_4307.png', 1),
#  ('./data/images/AD/coronal/031_S_0321.png', 1),
#  ('./data/images/AD/coronal/031_S_0554.png', 1),
#  ('./data/images/AD/coronal/031_S_0773.png', 1),
#  ('./data/images/AD/coronal/031_S_4024.png', 1),
#  ('./data/images/AD/coronal/032_S_1101.png', 1),
#  ('./data/images/AD/coronal/032_S_4755.png', 1),
#  ('./data/images/AD/coronal/032_S_6600.png', 1),
#  ('./data/images/AD/coronal/032_S_6602.png', 1),
#  ('./data/images/AD/coronal/032_S_6855.png', 1),
#  ('./data/images/AD/coronal/033_S_0724.png', 1),
#  ('./data/images/AD/coronal/033_S_0733.png', 1),
#  ('./data/images/AD/coronal/033_S_0739.png', 1),
#  ('./data/images/AD/coronal/033_S_0888.png', 1),
#  ('./data/images/AD/coronal/033_S_0889.png', 1),
#  ('./data/images/AD/coronal/033_S_1087.png', 1),
#  ('./data/images/AD/coronal/033_S_1281.png', 1),
#  ('./data/images/AD/coronal/033_S_1283.png', 1),
#  ('./data/images/AD/coronal/033_S_1285.png', 1),
#  ('./data/images/AD/coronal/033_S_1308.png', 1),
#  ('./data/images/AD/coronal/033_S_5013.png', 1),
#  ('./data/images/AD/coronal/033_S_5017.png', 1),
#  ('./data/images/AD/coronal/033_S_5087.png', 1),
#  ('./data/images/AD/coronal/033_S_6705.png', 1),
#  ('./data/images/AD/coronal/033_S_6824.png', 1),
#  ('./data/images/AD/coronal/033_S_6976.png', 1),
#  ('./data/images/AD/coronal/033_S_7066.png', 1),
#  ('./data/images/AD/coronal/035_S_0341.png', 1),
#  ('./data/images/AD/coronal/035_S_4783.png', 1),
#  ('./data/images/AD/coronal/035_S_6650.png', 1),
#  ('./data/images/AD/coronal/035_S_6660.png', 1),
#  ('./data/images/AD/coronal/035_S_6927.png', 1),
#  ('./data/images/AD/coronal/035_S_7001.png', 1),
#  ('./data/images/AD/coronal/036_S_0577.png', 1),
#  ('./data/images/AD/coronal/036_S_0759.png', 1),
#  ('./data/images/AD/coronal/036_S_0760.png', 1),
#  ('./data/images/AD/coronal/036_S_1001.png', 1),
#  ('./data/images/AD/coronal/036_S_4740.png', 1),
#  ('./data/images/AD/coronal/036_S_4820.png', 1),
#  ('./data/images/AD/coronal/036_S_4894.png', 1),
#  ('./data/images/AD/coronal/036_S_5063.png', 1),
#  ('./data/images/AD/coronal/036_S_5112.png', 1),
#  ('./data/images/AD/coronal/036_S_5149.png', 1),
#  ('./data/images/AD/coronal/036_S_5210.png', 1),
#  ('./data/images/AD/coronal/036_S_6179.png', 1),
#  ('./data/images/AD/coronal/036_S_6231.png', 1),
#  ('./data/images/AD/coronal/037_S_0627.png', 1),
#  ('./data/images/AD/coronal/037_S_4001.png', 1),
#  ('./data/images/AD/coronal/037_S_4770.png', 1),
#  ('./data/images/AD/coronal/037_S_4879.png', 1),
#  ('./data/images/AD/coronal/037_S_5162.png', 1),
#  ('./data/images/AD/coronal/037_S_6216.png', 1),
#  ('./data/images/AD/coronal/037_S_6230.png', 1),
#  ('./data/images/AD/coronal/037_S_6377.png', 1),
#  ('./data/images/AD/coronal/041_S_1368.png', 1),
#  ('./data/images/AD/coronal/041_S_1391.png', 1),
#  ('./data/images/AD/coronal/041_S_1435.png', 1),
#  ('./data/images/AD/coronal/051_S_1296.png', 1),
#  ('./data/images/AD/coronal/051_S_4980.png', 1),
#  ('./data/images/AD/coronal/051_S_5005.png', 1),
#  ('./data/images/AD/coronal/052_S_4959.png', 1),
#  ('./data/images/AD/coronal/052_S_5062.png', 1),
#  ('./data/images/AD/coronal/052_S_6305.png', 1),
#  ('./data/images/AD/coronal/053_S_1044.png', 1),
#  ('./data/images/AD/coronal/053_S_5070.png', 1),
#  ('./data/images/AD/coronal/053_S_5208.png', 1),
#  ('./data/images/AD/coronal/053_S_7109.png', 1),
#  ('./data/images/AD/coronal/057_S_0474.png', 1),
#  ('./data/images/AD/coronal/057_S_1371.png', 1),
#  ('./data/images/AD/coronal/057_S_1373.png', 1),
#  ('./data/images/AD/coronal/057_S_1379.png', 1),
#  ('./data/images/AD/coronal/057_S_4110.png', 1),
#  ('./data/images/AD/coronal/057_S_6746.png', 1),
#  ('./data/images/AD/coronal/057_S_6869.png', 1),
#  ('./data/images/AD/coronal/062_S_0535.png', 1),
#  ('./data/images/AD/coronal/062_S_0690.png', 1),
#  ('./data/images/AD/coronal/062_S_0730.png', 1),
#  ('./data/images/AD/coronal/062_S_0793.png', 1),
#  ('./data/images/AD/coronal/067_S_0020.png', 1),
#  ('./data/images/AD/coronal/067_S_0029.png', 1),
#  ('./data/images/AD/coronal/067_S_0076.png', 1),
#  ('./data/images/AD/coronal/067_S_0110.png', 1),
#  ('./data/images/AD/coronal/067_S_0828.png', 1),
#  ('./data/images/AD/coronal/067_S_4728.png', 1),
#  ('./data/images/AD/coronal/067_S_5205.png', 1),
#  ('./data/images/AD/coronal/067_S_7033.png', 1),
#  ('./data/images/AD/coronal/068_S_4859.png', 1),
#  ('./data/images/AD/coronal/068_S_4968.png', 1),
#  ('./data/images/AD/coronal/068_S_5146.png', 1),
#  ('./data/images/AD/coronal/068_S_5206.png', 1),
#  ('./data/images/AD/coronal/070_S_4692.png', 1),
#  ('./data/images/AD/coronal/070_S_4719.png', 1),
#  ('./data/images/AD/coronal/073_S_0565.png', 1),
#  ('./data/images/AD/coronal/073_S_1207.png', 1),
#  ('./data/images/AD/coronal/073_S_4853.png', 1),
#  ('./data/images/AD/coronal/073_S_5016.png', 1),
#  ('./data/images/AD/coronal/073_S_5090.png', 1),
#  ('./data/images/AD/coronal/082_S_1079.png', 1),
#  ('./data/images/AD/coronal/082_S_1377.png', 1),
#  ('./data/images/AD/coronal/082_S_5029.png', 1),
#  ('./data/images/AD/coronal/082_S_5184.png', 1),
#  ('./data/images/AD/coronal/082_S_6690.png', 1),
#  ('./data/images/AD/coronal/094_S_1027.png', 1),
#  ('./data/images/AD/coronal/094_S_1090.png', 1),
#  ('./data/images/AD/coronal/094_S_1102.png', 1),
#  ('./data/images/AD/coronal/094_S_1164.png', 1),
#  ('./data/images/AD/coronal/094_S_1397.png', 1),
#  ('./data/images/AD/coronal/094_S_1402.png', 1),
#  ('./data/images/AD/coronal/094_S_4282.png', 1),
#  ('./data/images/AD/coronal/094_S_4737.png', 1),
#  ('./data/images/AD/coronal/094_S_6736.png', 1),
#  ('./data/images/AD/coronal/098_S_0884.png', 1),
#  ('./data/images/AD/coronal/098_S_4201.png', 1),
#  ('./data/images/AD/coronal/098_S_4215.png', 1),
#  ('./data/images/AD/coronal/098_S_6601.png', 1),
#  ('./data/images/AD/coronal/098_S_6655.png', 1),
#  ('./data/images/AD/coronal/098_S_6658.png', 1),
#  ('./data/images/AD/coronal/099_S_0372.png', 1),
#  ('./data/images/AD/coronal/099_S_0470.png', 1),
#  ('./data/images/AD/coronal/099_S_0492.png', 1),
#  ('./data/images/AD/coronal/099_S_1144.png', 1),
#  ('./data/images/AD/coronal/099_S_4124.png', 1),
#  ('./data/images/AD/coronal/099_S_4994.png', 1),
#  ('./data/images/AD/coronal/100_S_5106.png', 1),
#  ('./data/images/AD/coronal/100_S_6713.png', 1),
#  ('./data/images/AD/coronal/109_S_0777.png', 1),
#  ('./data/images/AD/coronal/109_S_1157.png', 1),
#  ('./data/images/AD/coronal/109_S_1192.png', 1),
#  ('./data/images/CN/coronal/002_S_6007.png', 0),
#  ('./data/images/CN/coronal/002_S_6009.png', 0),
#  ('./data/images/CN/coronal/002_S_6030.png', 0),
#  ('./data/images/CN/coronal/002_S_6066.png', 0),
#  ('./data/images/CN/coronal/002_S_6103.png', 0),
#  ('./data/images/CN/coronal/002_S_6404.png', 0),
#  ('./data/images/CN/coronal/002_S_6456.png', 0),
#  ('./data/images/CN/coronal/002_S_6680.png', 0),
#  ('./data/images/CN/coronal/003_S_0931.png', 0),
#  ('./data/images/CN/coronal/003_S_6014.png', 0),
#  ('./data/images/CN/coronal/003_S_6067.png', 0),
#  ('./data/images/CN/coronal/003_S_6092.png', 0),
#  ('./data/images/CN/coronal/003_S_6256.png', 0),
#  ('./data/images/CN/coronal/003_S_6257.png', 0),
#  ('./data/images/CN/coronal/003_S_6259.png', 0),
#  ('./data/images/CN/coronal/003_S_6260.png', 0),
#  ('./data/images/CN/coronal/003_S_6307.png', 0),
#  ('./data/images/CN/coronal/003_S_6490.png', 0),
#  ('./data/images/CN/coronal/003_S_6644.png', 0),
#  ('./data/images/CN/coronal/003_S_6915.png', 0),
#  ('./data/images/CN/coronal/003_S_6924.png', 0),
#  ('./data/images/CN/coronal/003_S_6959.png', 0),
#  ('./data/images/CN/coronal/003_S_6996.png', 0),
#  ('./data/images/CN/coronal/003_S_7010.png', 0),
#  ('./data/images/CN/coronal/005_S_6084.png', 0),
#  ('./data/images/CN/coronal/005_S_6093.png', 0),
#  ('./data/images/CN/coronal/005_S_6393.png', 0),
#  ('./data/images/CN/coronal/006_S_6209.png', 0),
#  ('./data/images/CN/coronal/006_S_6234.png', 0),
#  ('./data/images/CN/coronal/006_S_6277.png', 0),
#  ('./data/images/CN/coronal/006_S_6375.png', 0),
#  ('./data/images/CN/coronal/006_S_6500.png', 0),
#  ('./data/images/CN/coronal/007_S_6120.png', 0),
#  ('./data/images/CN/coronal/007_S_6255.png', 0),
#  ('./data/images/CN/coronal/007_S_6310.png', 0),
#  ('./data/images/CN/coronal/007_S_6323.png', 0),
#  ('./data/images/CN/coronal/007_S_6455.png', 0),
#  ('./data/images/CN/coronal/007_S_6515.png', 0),
#  ('./data/images/CN/coronal/007_S_6521.png', 0),
#  ('./data/images/CN/coronal/009_S_6163.png', 0),
#  ('./data/images/CN/coronal/009_S_6212.png', 0),
#  ('./data/images/CN/coronal/009_S_6286.png', 0),
#  ('./data/images/CN/coronal/010_S_6567.png', 0),
#  ('./data/images/CN/coronal/011_S_0002.png', 0),
#  ('./data/images/CN/coronal/011_S_6367.png', 0),
#  ('./data/images/CN/coronal/011_S_6418.png', 0),
#  ('./data/images/CN/coronal/011_S_6465.png', 0),
#  ('./data/images/CN/coronal/011_S_6714.png', 0),
#  ('./data/images/CN/coronal/011_S_7028.png', 0),
#  ('./data/images/CN/coronal/011_S_7048.png', 0),
#  ('./data/images/CN/coronal/011_S_7112.png', 0),
#  ('./data/images/CN/coronal/012_S_4642.png', 0),
#  ('./data/images/CN/coronal/012_S_4643.png', 0),
#  ('./data/images/CN/coronal/013_S_0502.png', 0),
#  ('./data/images/CN/coronal/013_S_0575.png', 0),
#  ('./data/images/CN/coronal/013_S_1035.png', 0),
#  ('./data/images/CN/coronal/013_S_4579.png', 0),
#  ('./data/images/CN/coronal/013_S_4580.png', 0),
#  ('./data/images/CN/coronal/013_S_4616.png', 0),
#  ('./data/images/CN/coronal/013_S_6780.png', 0),
#  ('./data/images/CN/coronal/013_S_7103.png', 0),
#  ('./data/images/CN/coronal/014_S_0519.png', 0),
#  ('./data/images/CN/coronal/014_S_0520.png', 0),
#  ('./data/images/CN/coronal/014_S_0548.png', 0),
#  ('./data/images/CN/coronal/014_S_0558.png', 0),
#  ('./data/images/CN/coronal/014_S_4080.png', 0),
#  ('./data/images/CN/coronal/014_S_4093.png', 0),
#  ('./data/images/CN/coronal/014_S_4401.png', 0),
#  ('./data/images/CN/coronal/014_S_4576.png', 0),
#  ('./data/images/CN/coronal/014_S_4577.png', 0),
#  ('./data/images/CN/coronal/014_S_6076.png', 0),
#  ('./data/images/CN/coronal/014_S_6145.png', 0),
#  ('./data/images/CN/coronal/014_S_6148.png', 0),
#  ('./data/images/CN/coronal/014_S_6199.png', 0),
#  ('./data/images/CN/coronal/014_S_6210.png', 0),
#  ('./data/images/CN/coronal/014_S_6366.png', 0),
#  ('./data/images/CN/coronal/014_S_6424.png', 0),
#  ('./data/images/CN/coronal/014_S_6437.png', 0),
#  ('./data/images/CN/coronal/014_S_6502.png', 0),
#  ('./data/images/CN/coronal/014_S_6522.png', 0),
#  ('./data/images/CN/coronal/014_S_6831.png', 0),
#  ('./data/images/CN/coronal/014_S_6920.png', 0),
#  ('./data/images/CN/coronal/014_S_6935.png', 0),
#  ('./data/images/CN/coronal/014_S_6988.png', 0),
#  ('./data/images/CN/coronal/014_S_7072.png', 0),
#  ('./data/images/CN/coronal/014_S_7080.png', 0),
#  ('./data/images/CN/coronal/016_S_0359.png', 0),
#  ('./data/images/CN/coronal/016_S_0538.png', 0),
#  ('./data/images/CN/coronal/016_S_4097.png', 0),
#  ('./data/images/CN/coronal/016_S_4638.png', 0),
#  ('./data/images/CN/coronal/016_S_4688.png', 0),
#  ('./data/images/CN/coronal/016_S_4951.png', 0),
#  ('./data/images/CN/coronal/016_S_4952.png', 0),
#  ('./data/images/CN/coronal/016_S_6381.png', 0),
#  ('./data/images/CN/coronal/016_S_6773.png', 0),
#  ('./data/images/CN/coronal/016_S_6790.png', 0),
#  ('./data/images/CN/coronal/016_S_6802.png', 0),
#  ('./data/images/CN/coronal/016_S_6834.png', 0),
#  ('./data/images/CN/coronal/016_S_6853.png', 0),
#  ('./data/images/CN/coronal/016_S_6892.png', 0),
#  ('./data/images/CN/coronal/016_S_6931.png', 0),
#  ('./data/images/CN/coronal/016_S_6934.png', 0),
#  ('./data/images/CN/coronal/016_S_6941.png', 0),
#  ('./data/images/CN/coronal/016_S_6943.png', 0),
#  ('./data/images/CN/coronal/016_S_6971.png', 0),
#  ('./data/images/CN/coronal/018_S_0043.png', 0),
#  ('./data/images/CN/coronal/018_S_0055.png', 0),
#  ('./data/images/CN/coronal/018_S_0369.png', 0),
#  ('./data/images/CN/coronal/018_S_4257.png', 0),
#  ('./data/images/CN/coronal/018_S_4313.png', 0),
#  ('./data/images/CN/coronal/018_S_4349.png', 0),
#  ('./data/images/CN/coronal/018_S_4399.png', 0),
#  ('./data/images/CN/coronal/018_S_4400.png', 0),
#  ('./data/images/CN/coronal/018_S_6207.png', 0),
#  ('./data/images/CN/coronal/018_S_6351.png', 0),
#  ('./data/images/CN/coronal/019_S_4367.png', 0),
#  ('./data/images/CN/coronal/019_S_4835.png', 0),
#  ('./data/images/CN/coronal/019_S_6186.png', 0),
#  ('./data/images/CN/coronal/019_S_7016.png', 0),
#  ('./data/images/CN/coronal/020_S_0097.png', 0),
#  ('./data/images/CN/coronal/020_S_0883.png', 0),
#  ('./data/images/CN/coronal/020_S_0899.png', 0),
#  ('./data/images/CN/coronal/020_S_6185.png', 0),
#  ('./data/images/CN/coronal/020_S_6227.png', 0),
#  ('./data/images/CN/coronal/020_S_6282.png', 0),
#  ('./data/images/CN/coronal/020_S_6358.png', 0),
#  ('./data/images/CN/coronal/020_S_6449.png', 0),
#  ('./data/images/CN/coronal/020_S_6470.png', 0),
#  ('./data/images/CN/coronal/020_S_6504.png', 0),
#  ('./data/images/CN/coronal/020_S_6513.png', 0),
#  ('./data/images/CN/coronal/020_S_6566.png', 0),
#  ('./data/images/CN/coronal/021_S_0159.png', 0),
#  ('./data/images/CN/coronal/021_S_0337.png', 0),
#  ('./data/images/CN/coronal/021_S_0647.png', 0),
#  ('./data/images/CN/coronal/021_S_0984.png', 0),
#  ('./data/images/CN/coronal/021_S_4254.png', 0),
#  ('./data/images/CN/coronal/021_S_4276.png', 0),
#  ('./data/images/CN/coronal/021_S_4335.png', 0),
#  ('./data/images/CN/coronal/021_S_4421.png', 0),
#  ('./data/images/CN/coronal/021_S_4558.png', 0),
#  ('./data/images/CN/coronal/021_S_6312.png', 0),
#  ('./data/images/CN/coronal/021_S_6896.png', 0),
#  ('./data/images/CN/coronal/021_S_6910.png', 0),
#  ('./data/images/CN/coronal/021_S_6914.png', 0),
#  ('./data/images/CN/coronal/021_S_6918.png', 0),
#  ('./data/images/CN/coronal/021_S_6940.png', 0),
#  ('./data/images/CN/coronal/021_S_6987.png', 0),
#  ('./data/images/CN/coronal/021_S_6994.png', 0),
#  ('./data/images/CN/coronal/021_S_7045.png', 0),
#  ('./data/images/CN/coronal/021_S_7055.png', 0),
#  ('./data/images/CN/coronal/021_S_7062.png', 0),
#  ('./data/images/CN/coronal/021_S_7092.png', 0),
#  ('./data/images/CN/coronal/022_S_0014.png', 0),
#  ('./data/images/CN/coronal/022_S_0066.png', 0),
#  ('./data/images/CN/coronal/022_S_0096.png', 0),
#  ('./data/images/CN/coronal/022_S_0130.png', 0),
#  ('./data/images/CN/coronal/022_S_4173.png', 0),
#  ('./data/images/CN/coronal/022_S_4196.png', 0),
#  ('./data/images/CN/coronal/022_S_4266.png', 0),
#  ('./data/images/CN/coronal/022_S_4291.png', 0),
#  ('./data/images/CN/coronal/022_S_4320.png', 0),
#  ('./data/images/CN/coronal/022_S_6069.png', 0),
#  ('./data/images/CN/coronal/022_S_6797.png', 0),
#  ('./data/images/CN/coronal/022_S_6822.png', 0),
#  ('./data/images/CN/coronal/023_S_0058.png', 0),
#  ('./data/images/CN/coronal/023_S_0081.png', 0),
#  ('./data/images/CN/coronal/023_S_0926.png', 0),
#  ('./data/images/CN/coronal/023_S_0963.png', 0),
#  ('./data/images/CN/coronal/023_S_1190.png', 0),
#  ('./data/images/CN/coronal/023_S_1306.png', 0),
#  ('./data/images/CN/coronal/023_S_4020.png', 0),
#  ('./data/images/CN/coronal/023_S_4164.png', 0),
#  ('./data/images/CN/coronal/023_S_4448.png', 0),
#  ('./data/images/CN/coronal/023_S_6270.png', 0),
#  ('./data/images/CN/coronal/023_S_6346.png', 0),
#  ('./data/images/CN/coronal/023_S_6374.png', 0),
#  ('./data/images/CN/coronal/023_S_6399.png', 0),
#  ('./data/images/CN/coronal/023_S_6400.png', 0),
#  ('./data/images/CN/coronal/023_S_6547.png', 0),
#  ('./data/images/CN/coronal/023_S_6795.png', 0),
#  ('./data/images/CN/coronal/024_S_0985.png', 0),
#  ('./data/images/CN/coronal/024_S_1063.png', 0),
#  ('./data/images/CN/coronal/024_S_4084.png', 0),
#  ('./data/images/CN/coronal/024_S_4158.png', 0),
#  ('./data/images/CN/coronal/024_S_6005.png', 0),
#  ('./data/images/CN/coronal/024_S_6184.png', 0),
#  ('./data/images/CN/coronal/024_S_6202.png', 0),
#  ('./data/images/CN/coronal/024_S_6385.png', 0),
#  ('./data/images/CN/coronal/024_S_6472.png', 0),
#  ('./data/images/CN/coronal/027_S_0074.png', 0),
#  ('./data/images/CN/coronal/027_S_0118.png', 0),
#  ('./data/images/CN/coronal/027_S_0120.png', 0),
#  ('./data/images/CN/coronal/027_S_0403.png', 0),
#  ('./data/images/CN/coronal/027_S_6001.png', 0),
#  ('./data/images/CN/coronal/027_S_6183.png', 0),
#  ('./data/images/CN/coronal/027_S_6317.png', 0),
#  ('./data/images/CN/coronal/027_S_6327.png', 0),
#  ('./data/images/CN/coronal/027_S_6516.png', 0),
#  ('./data/images/CN/coronal/027_S_6577.png', 0),
#  ('./data/images/CN/coronal/027_S_6582.png', 0)]

# %%
# Define the data loader and transformations
class ImageDataset(Dataset):
    def __init__(self, data, transform=None):
        self.data = data
        self.transform = transform

    def __len__(self):
        return len(self.data)

    def __getitem__(self, index):
        img_path, label = self.data[index]
        img = Image.open(img_path).convert("RGB")
        if self.transform is not None:
            img = self.transform(img)
        return img, label

# %%
# Define transforms
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

# %%
# 5-Fold Cross-Validation
from sklearn.metrics import accuracy_score
import torchvision

kf = KFold(n_splits=5)
fold_results = []

for fold, (train_ids, test_ids) in enumerate(kf.split(data)):
    # Split data
    train_subsampler = torch.utils.data.SubsetRandomSampler(train_ids)
    test_subsampler = torch.utils.data.SubsetRandomSampler(test_ids)

    # Create data loaders
    dataset = ImageDataset(data, transform=transform)
    train_loader = DataLoader(dataset, batch_size=16, sampler=train_subsampler)
    test_loader = DataLoader(dataset, batch_size=16, sampler=test_subsampler)

    # Load a pretrained ViT model

    # 1. Get pretrained weights for ViT-Base
    pretrained_vit_weights = torchvision.models.ViT_B_16_Weights.DEFAULT 

    # 2. Setup a ViT model instance with pretrained weights
    pretrained_vit = torchvision.models.vit_b_16(weights=pretrained_vit_weights).to(device)

    # 3. Freeze the base parameters
    for parameter in pretrained_vit.parameters():
        parameter.requires_grad = False

    # 4. Change the classifier head 
    class_names = [0,1]


    pretrained_vit.heads = nn.Linear(in_features=768, out_features=2).to(device)
    pretrained_vit_transforms = pretrained_vit_weights.transforms()
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

    pretrained_vit.to(device)

    # Loss Function, Optimizer

    optimizer = torch.optim.Adam(params=pretrained_vit.parameters(), lr=1e-3)
    criterion = torch.nn.CrossEntropyLoss()

    train_f1_scores, train_accuracies = [], []
    test_f1_scores, test_accuracies = [], []

    # Training Loop for this fold
    for epoch in range(30):  # Number of epochs
        pretrained_vit.train()
        train_targets, train_predictions = [], []
        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = pretrained_vit(images)
            _, predicted = torch.max(outputs.data, 1)
            train_targets.extend(labels.cpu().numpy())
            train_predictions.extend(predicted.cpu().numpy())
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

        
        # Calculate training metrics
        train_f1 = f1_score(train_targets, train_predictions, average='weighted')
        train_acc = accuracy_score(train_targets, train_predictions)
        train_f1_scores.append(train_f1)
        train_accuracies.append(train_acc)

    # Evaluation for this fold
    pretrained_vit.eval()
    test_targets, test_predictions = [], []
    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = pretrained_vit(images)
            _, predicted = torch.max(outputs.data, 1)
            test_targets.extend(labels.cpu().numpy())
            test_predictions.extend(predicted.cpu().numpy())

    # Calculate testing metrics
    test_f1 = f1_score(test_targets, test_predictions, average='weighted')
    test_acc = accuracy_score(test_targets, test_predictions)
    test_f1_scores.append(test_f1)
    test_accuracies.append(test_acc)

    # Print fold results
    print(f"Fold {fold + 1}")
    print(f"Training F1 Score: {np.mean(train_f1_scores)}, Training Accuracy: {np.mean(train_accuracies)}")
    print(f"Testing F1 Score: {test_f1}, Testing Accuracy: {test_acc}")

    # Store results for averaging later
    fold_results.append({
        'fold': fold + 1,
        'train_f1': np.mean(train_f1_scores),
        'train_accuracy': np.mean(train_accuracies),
        'test_f1': test_f1,
        'test_accuracy': test_acc
    })

# Average results over all folds
avg_train_f1 = np.mean([result['train_f1'] for result in fold_results])
avg_train_accuracy = np.mean([result['train_accuracy'] for result in fold_results])
avg_test_f1 = np.mean([result['test_f1'] for result in fold_results])
avg_test_accuracy = np.mean([result['test_accuracy'] for result in fold_results])

print(f"Average Training F1 Score: {avg_train_f1}, Average Training Accuracy: {avg_train_accuracy}")
print(f"Average Testing F1 Score: {avg_test_f1}, Average Testing Accuracy: {avg_test_accuracy}")
# Out:
# Fold 1
# Training F1 Score: 0.7905194783839895, Training Accuracy: 0.790819209039548
# Testing F1 Score: 0.6662813200803374, Testing Accuracy: 0.6694915254237288
# Fold 2
# Training F1 Score: 0.7774603728976527, Training Accuracy: 0.7790254237288133
# Testing F1 Score: 0.6933840498810778, Testing Accuracy: 0.6694915254237288
# Fold 3
# Training F1 Score: 0.7883825011019767, Training Accuracy: 0.7932203389830509
# Testing F1 Score: 0.6436781609195402, Testing Accuracy: 0.4745762711864407
# Fold 4
# Training F1 Score: 0.7669970401446842, Training Accuracy: 0.7685734463276835
# Testing F1 Score: 0.7583524033795859, Testing Accuracy: 0.7542372881355932
# Fold 5
# Training F1 Score: 0.7731772613116461, Training Accuracy: 0.780508474576271
# Testing F1 Score: 0.8020304568527918, Testing Accuracy: 0.6694915254237288
# Average Training F1 Score: 0.7793073307679899, Average Training Accuracy: 0.7824293785310734
# Average Testing F1 Score: 0.7127452782226666, Average Testing Accuracy: 0.6474576271186441
